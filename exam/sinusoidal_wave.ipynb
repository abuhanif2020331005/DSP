# %%
import numpy as np
import matplotlib.pyplot as plt
f=4
fs=1000
l=2000
t=np.linspace(0,(l-1)/fs,l)
s=1.0*np.sin(2*np.pi*f*t)
print(t)
plt.figure(figsize=(8,4))
plt.plot(t,s,label="sinusoidal wave")
plt.xlabel("time(s)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0.000e+00 1.000e-03 2.000e-03 ... 1.997e+00 1.998e+00 1.999e+00]
