# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(-6,5)
print(t)
s=[1 if i == 0 else 0 for i in t]
plt.stem(t,s)
# Out:
# [-6 -5 -4 -3 -2 -1  0  1  2  3  4]
# <StemContainer object of 3 artists>

# %%
t=np.arange(-11,10)
s=[1 if i>=0 else 0 for i in t]
plt.stem(t,s)
# Out:
# <StemContainer object of 3 artists>

# %%
s=[i if i>0 else 0 for i in t]
plt.stem(t,s)
# Out:
# <StemContainer object of 3 artists>
